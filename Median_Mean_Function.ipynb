# %% [markdown]
# # CSV import

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
bikingDataFramePhone = pd.read_csv('BikingFormated2.csv')
bikingDataPhone = bikingDataFramePhone.as_matrix()

bikingDataFrameGR = pd.read_csv('BikingFormated1.csv')
bikingDataGR = bikingDataFrameGR.as_matrix()

# %%
bikingDataFramePhone
# Out:
#      56.2568605075  10.0688809242
# 0        56.256929      10.069019
# 1        56.256928      10.069044
# 2        56.256942      10.069060
# 3        56.256958      10.069054
# 4        56.256972      10.069064
# 5        56.256985      10.069059
# 6        56.256994      10.069052
# 7        56.257002      10.069043
# 8        56.257006      10.069036
# 9        56.257011      10.069031
# 10       56.257016      10.069027
# 11       56.257021      10.069024
# 12       56.257026      10.069021
# 13       56.257028      10.069019
# 14       56.257029      10.069018
# 15       56.257030      10.069018
# 16       56.257031      10.069018
# 17       56.257034      10.069018
# 18       56.257035      10.069018
# 19       56.257036      10.069018
# 20       56.257039      10.069019
# 21       56.257039      10.069020
# 22       56.257040      10.069020
# 23       56.257041      10.069020
# 24       56.257041      10.069020
# 25       56.257042      10.069021
# ...

# %%
plt.scatter(bikingDataGR[:,0],bikingDataGR[:,1])
plt.show()

# %%
plt.scatter(bikingDataPhone[:,0],bikingDataPhone[:,1])
plt.show()
